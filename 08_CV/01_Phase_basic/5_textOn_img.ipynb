# %%
import cv2

# %%
img_get = cv2.imread('img_3.jpg')
img_get = cv2.resize(img_get, (500, 700))


txt = cv2.putText(img = img_get,
text = "Deveraonda",
org = (50, 80),
fontFace = cv2.FONT_HERSHEY_SIMPLEX,
fontScale = 3,
color = (0, 0, 255),  # Red color in BGR
thickness = 3,
lineType = cv2.LINE_8,
bottomLeftOrigin = False)


cv2.imshow('Actor image', txt)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Mirror text

# %%
img_get = cv2.imread('img_3.jpg')
img_get = cv2.resize(img_get, (500, 700))


txt = cv2.putText(img = img_get,
text = "Deveraonda",
org = (50, 80),
fontFace = cv2.FONT_HERSHEY_SIMPLEX,
fontScale = 3,
color = (255, 0, 0),  # Red color in BGR
thickness = 3,
lineType = cv2.LINE_8,
bottomLeftOrigin = False)

txt = cv2.putText(img = txt,
text = "Deveraonda",
org = (50, 80),
fontFace = cv2.FONT_HERSHEY_SIMPLEX,
fontScale = 3,
color = (0, 0, 255),  # Red color in BGR
thickness = 3,
lineType = cv2.LINE_8,
bottomLeftOrigin = True)


cv2.imshow('Actor image', txt)
cv2.waitKey(0)
cv2.destroyAllWindows()
