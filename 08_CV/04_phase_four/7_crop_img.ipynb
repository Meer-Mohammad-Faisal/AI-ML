# %%
import cv2

# %%
img = cv2.imread('img_1.jpg')
img = cv2.resize(img, (600, 500))

#print(img)
# img[[y1:y2, x1:x2]]
crop = img[70:290, 200:330]
cv2.imshow('Cropped Image', crop)


cv2.imshow('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
