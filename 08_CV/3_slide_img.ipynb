# %%
import cv2
import numpy as np
import os

# %%
list_name = os.listdir(r"C:\Users\ASUS\Downloads\image")
list_name
# Out:
# ['img_1.jpg', 'img_2.jpg', 'img_3.jpg', 'img_4.jpg']

# %%
for name in list_name:
    path = "C:\\Users\\ASUS\\Downloads\\image"
    img_name = path + "\\" + name
    img = cv2.imread(img_name)
    img = cv2.resize(img,(500, 600))
    cv2.imshow("Actor", img)
    cv2.waitKey(0)
cv2.destroyAllWindows()
