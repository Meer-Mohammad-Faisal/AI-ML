# %%
# word tokenization
sent1 = "I am going to home"
sent1.split()
# Out:
# ['I', 'am', 'going', 'to', 'home']

# %%
# sentence tokenization
sent2 = "i am going to home. what about you. when will you reach?"
sent2.split('.')
# Out:
# ['i am going to home', ' what about you', ' when will you reach?']

# %%
# problem with split function
sent3 = 'I am going Banglore!'
sent3.split()
# Out:
# ['I', 'am', 'going', 'Banglore!']

# %%
sent4 = "i am going to home; what about you? when will you reach! thannks."
sent4.split()
# Out:
# ['i',
#  'am',
#  'going',
#  'to',
#  'home;',
#  'what',
#  'about',
#  'you?',
#  'when',
#  'will',
#  'you',
#  'reach!',
#  'thannks.']
